# %%
import pandas as pd

# %% [markdown]
# # Работа с Pandas

# %% [markdown]
# ## Задание 1
# Загрузите ваш DataFrame в переменную df и выведете на экран первые пять строк

# %%
import pandas as pd

df = pd.read_csv('googleplaystore.csv', encoding='latin-1')
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4,1
# 1                                Coloring book moana  ART_AND_DESIGN    3,9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN    4,7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4,5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4,3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8,7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2,8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018              1,00.0
# 1  Art & Design;Pretend Play  January 15, 2018              2,00.0
# 2               Art & Design    August 1, 2018              1,20.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1,1
#
#     Android Ver  Unnamed: 13  Unnamed: 14
# 0  4.0.3 and up          NaN          NaN
# 1  4.0.3 and up          NaN          NaN
# 2  4.0.3 and up          NaN          NaN
# 3    4.2 and up          NaN          NaN
# 4    4.4 and up          NaN          NaN

# %% [markdown]
# Отобразите количество строк и столбцов в DataFrame

# %%
info = df.shape
print(f"Количество строк : {info[0]}, Количество столбцов : {info[1]}")
# Out:
# Количество строк : 10842, Количество столбцов : 15

# %% [markdown]
# Измените названия всех столбцов приведя их к нижнему регистру, а вмето пробелов поставить нижнее подчеркиание

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
print(df.columns)
# Out:
# Index(['app', 'category', 'rating', 'reviews', 'size', 'installs', 'type',
#        'price', 'content_rating', 'genres', 'last_updated', 'current_ver',
#        'android_ver', 'unnamed:_13', 'unnamed:_14'],
#       dtype='object')

# %% [markdown]
# Выведите основные статистики по категориальным столбцам. Напишите выводы о них

# %%
categorical_stats = df.describe(include='object')
print(categorical_stats.to_string())

'''
Большинство приложений бесплатные (Free) и рассчитаны на всех пользователей (Everyone).
Наиболее популярные категории — Family, жанры — Tools.
Рейтинги в целом высокие, чаще всего 4,4.
Многие приложения имеют 0 отзывов или размер/версию, зависящие от устройства (Varies with device).

'''
# Out:
#            app category rating reviews                size    installs   type  price content_rating genres    last_updated         current_ver android_ver
# count    10841    10841   9367   10841               10841       10841  10840  10841          10840  10841           10841               10833       10838
# unique    9660       34     40    6002                 462          22      3     92              6    120            1378                2830          33
# top     ROBLOX   FAMILY    4,4       0  Varies with device  1,000,000+   Free      0       Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq         9     1972   1109     596                1695        1579  10039  10041           8714    842             326                1459        2451
# '\nБольшинство приложений бесплатные (Free) и рассчитаны на всех пользователей (Everyone).\nНаиболее популярные категории — Family, жанры — Tools.\nРейтинги в целом высокие, чаще всего 4,4.\nМногие приложения имеют 0 отзывов или размер/версию, зависящие от устройства (Varies with device).\n\n'

# %% [markdown]
# ## Задание 2
# Выведите на экран часть датафрейма, который соответствует условию: `приложение из категории искусства и дизайна` И `с рейтингом больше 4.5`

# %%
df['rating'] = df['rating'].str.replace(',', '.').astype(float)
art_high_rating = df[(df['category'] == 'ART_AND_DESIGN') & (df['rating'] > 4.5)]
art_high_rating
# Out:
#                                                     app        category  \
# 2     U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 34                                      I Creative Idea  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# 45    Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 46    Install images with music to make video withou...  ART_AND_DESIGN
# 3983                                  Cardi B Wallpaper  ART_AND_DESIGN
# 4750  X Launcher: With OS11 Style Theme & Control Ce...  ART_AND_DESIGN
# 4756  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4760  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# 4765     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 5255                            AJ Styles HD Wallpapers  ART_AND_DESIGN
# 6931               Fantasy theme dark bw black building  ART_AND_DESIGN
# 8889            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       rating reviews  size     installs  type price content_rating  \
# 2        4.7   87510  8,7M   5,000,000+  Free     0       Everyone
# 9        4.7     121  3,1M      10,000+  Free     0       Everyone
# 13       4.6    4326   21M     100,000+  Free     0       Everyone
# 16       4.7    3632  5,5M     500,000+  Free     0       Everyone
# 19       4.6  224399   31M  10,000,000+  Free     0       Everyone
# 22       4.7    7699  4,2M     500,000+  Free     0   Everyone 10+
# 24       4.7     118   23M      50,000+  Free     0       Everyone
# 25       4.8     192  6,0M      10,000+  Free     0       Everyone
# 26       4.7   20260   25M     500,000+  Free     0       Everyone
# 34       4.7     353  4,2M      10,000+  Free     0           Teen
# 36       4.7    8145   24M     500,000+  Free     0       Everyone
# 38       4.7     158   11M      10,000+  Free     0       Everyone
# 45       4.7  174531   24M  10,000,000+  Free     0       Everyone
# 46       4.6    1070   26M     100,000+  Free     0       Everyone
# 3983     4.8     253  3,7M      50,000+  Free     0       Everyone
# 4750     4.7    5754  4,4M     100,000+  Free     0       Everyone
# 4756     4.7     801  3,5M       5,000+  Paid  1,99       Everyone
# 4760     4.8    1216  8,6M      10,000+  Paid  1,99       Everyone
# 4765     4.7     149  3,5M       1,000+  Paid  1,99       Everyone
# 5255     4.8      48   25M       5,000+  Free     0       Everyone
# 6931     4.8      41  1,9M       5,000+  Free     0       Everyone
# 8889     5.0       1  2,9M         100+  Free     0       Everyone
#
#                        genres       last_updated current_ver   android_ver  \
# 2                Art & Design     August 1, 2018      1,20.4  4.0.3 and up
# 9     Art & Design;Creativity       July 3, 2018         2,8  4.0.3 and up
# 13               Art & Design      June 26, 2018      1,00.4    4.4 and up
# 16               Art & Design      July 31, 2018         3,1    4.1 and up
# 19               Art & Design      July 30, 2018      5,50.4    4.1 and up
# 22               Art & Design      July 12, 2018     2.2.6.2  4.0.3 and up
# 24               Art & Design       July 7, 2018      1,10.3    4.1 and up
# 25               Art & Design     April 25, 2018         1,5    3.0 and up
# 26    Art & Design;Creativity   October 11, 2017      1,00.8  4.0.3 and up
# 34               Art & Design     April 27, 2018         1,6    4.1 and up
# 36    Art & Design;Creativity     August 2, 2018      1,00.9    4.4 and up
# 38               Art & Design  November 29, 2017         1,3  4.0.3 and up
# 45               Art & Design      July 31, 2018      1,60.1    4.1 and up
# 46               Art & Design  November 14, 2017         1,6    4.1 and up
# 3983             Art & Design   November 1, 2017      1,00.0    4.0 and up
# 4750             Art & Design      July 30, 2018      2,10.2    4.1 and up
# 4756             Art & Design      July 30, 2018      2,10.2    4.1 and up
# 4760             Art & Design      June 26, 2018      1,00.0    4.1 and up
# 4765             Art & Design      July 30, 2018      1,20.2    4.1 and up
# 5255             Art & Design     August 4, 2018      1,10.1    4.1 and up
# 6931             Art & Design     March 20, 2018      1,00.2    4.0 and up
# 8889             Art & Design     April 18, 2018      1,00.2    4.0 and up
#
#       unnamed:_13  unnamed:_14
# 2             NaN          NaN
# 9             NaN          NaN
# 13            NaN          NaN
# 16            NaN          NaN
# 19            NaN          NaN
# 22            NaN          NaN
# 24            NaN          NaN
# 25            NaN          NaN
# 26            NaN          NaN
# 34            NaN          NaN
# 36            NaN          NaN
# 38            NaN          NaN
# 45            NaN          NaN
# 46            NaN          NaN
# 3983          NaN          NaN
# 4750          NaN          NaN
# 4756          NaN          NaN
# 4760          NaN          NaN
# 4765          NaN          NaN
# 5255          NaN          NaN
# 6931          NaN          NaN
# 8889          NaN          NaN

# %% [markdown]
# ## Задание 3
# Посчитатайте какое количество игр содержится в рейтинге, используя параметр разбиения (bins) равным 100. Выведите на экран топ-10 игр по количеству в рейтинге. Напишите краткий вывод.
# То есть сначала отфильтровываете лишь игры из всего датафрейма, после чего применяете value_counts к столбцу с рейтингом используя параметр, который указан выше. И выводите первые 10 строк отсортированных по убыванию.

# %%
games_df = df[df['category'] == 'GAME'].copy()
rating_counts = pd.cut(games_df['rating'], bins=100).value_counts().sort_values(ascending=False)
rating_counts.head(10)

'''
большинство игр получают рейтинг от 4.0 до 4.52
'''
# Out:
# rating
# (4.48, 4.52]    174
# (4.36, 4.4]     166
# (4.28, 4.32]    151
# (4.56, 4.6]     121
# (4.16, 4.2]     115
# (4.08, 4.12]     72
# (4.68, 4.72]     67
# (3.96, 4.0]      55
# (3.76, 3.8]      41
# (3.88, 3.92]     35
# Name: count, dtype: int64

# %% [markdown]
# ## Задание 4
# Выведите кол-во уникальных значений в столбцах отсортированных по убыванию на экран:

# %%
unique_counts = df.nunique()
unique_counts.sort_values(ascending=False)
# Out:
# app               9660
# reviews           6002
# current_ver       2830
# last_updated      1378
# size               462
# genres             120
# price               92
# rating              40
# category            34
# android_ver         33
# installs            22
# content_rating       6
# type                 3
# unnamed:_13          0
# unnamed:_14          0
# dtype: int64

# %% [markdown]
# ## Задание 5
# Изучите функцию `transform` в документации Pandas. Примените её к датафрейму, который будет заранее сгруппирован по столбцу `category`. С помощью фукнции `transform` найдите средний `rating` по каждой категории и запишите в столбец с названием `mean_cat_rating`. Кол-во строк в получившемся новом столбец должно быть таким же, как и в исходном датафрейме

# %%
df['mean_cat_rating'] = df.groupby('category')['rating'].transform('mean')
df[['category', 'rating', 'mean_cat_rating']]
# Out:
#                   category  rating  mean_cat_rating
# 0           ART_AND_DESIGN     4.1         4.358065
# 1           ART_AND_DESIGN     3.9         4.358065
# 2           ART_AND_DESIGN     4.7         4.358065
# 3           ART_AND_DESIGN     4.5         4.358065
# 4           ART_AND_DESIGN     4.3         4.358065
# ...                    ...     ...              ...
# 10837               FAMILY     4.5         4.192272
# 10838               FAMILY     5.0         4.192272
# 10839              MEDICAL     NaN         4.189143
# 10840  BOOKS_AND_REFERENCE     4.5         4.346067
# 10841            LIFESTYLE     4.5         4.094904
#
# [10842 rows x 3 columns]

# %%
#FYcrixyfbNGgjYWHgTsPWC83Vp
